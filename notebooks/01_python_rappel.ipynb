# %% [markdown]
# <a href="https://colab.research.google.com/github/kaneserignembacke260-beep/titanic-ml-pipeline/blob/main/01_python_rappel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
passager = {"nom": "Dupont", "age": 29, "survecu": True}
print(passager)
passagers = [
    {"nom": "Dupont", "age": 29, "survecu": True},
    {"nom": "Martin", "age": 41, "survecu": False},
    {"nom": "Bernard", "age": 22, "survecu": True}
]
print(passagers)
for p in passagers:
    if p["survecu"]:
        print(p["nom"])
# Out:
# {'nom': 'Dupont', 'age': 29, 'survecu': True}
# [{'nom': 'Dupont', 'age': 29, 'survecu': True}, {'nom': 'Martin', 'age': 41, 'survecu': False}, {'nom': 'Bernard', 'age': 22, 'survecu': True}]
# Dupont
# Bernard
